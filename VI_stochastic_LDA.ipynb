# %%
import numpy as np
import pandas as pd
from collections import Counter
from scipy.special import digamma
from scipy.special import gamma
from scipy.special import gammaln
import time

import pickle

# %%
class LDA:
    
    def __init__(self, fn, K):
        data = pd.read_csv(fn,sep='\t',index_col = 0)
        np.random.seed(2)
        data = data.iloc[np.random.choice(range(len(data)),5000)]
        words_in_each_gene = data.groupby(data.index).sum()

        words_in_txt = [np.repeat(np.array(words_in_each_gene.columns), t.astype('int'),axis=0) for t in np.array(np.ceil(words_in_each_gene))]
        allwords = [a for b in words_in_txt for a in b]
        vocabulary = np.unique(allwords)
        vocabulary_in_int = dict(zip(vocabulary, range(len(vocabulary))))
        self.vocabulary_in_int = vocabulary_in_int

        self.K = K
        self.M = len(words_in_each_gene)
        self.V = len(vocabulary)
        print 'M = %d, V = %d, total number of words = %d' % (self.M, self.V, len(allwords))

        W = [[vocabulary_in_int[t] for t in wd] for wd in words_in_txt]
        self.Nd = [len(wd) for wd in W]
        self.alphii = 1/float(self.K)
        self.etaj = 1/float(self.V)
        
        ### generate W matrix: D x [Nd, V]
        self.Wn = [np.zeros([self.Nd[t],self.V]) for t in range(self.M)]
        for d in range(self.M):
            for token in xrange(self.Nd[d]):
                self.Wn[d][token, W[d][token]] = 1 
          
        
        #### initialization -- set the strucutres, values don't matter
        self.phi = [np.ones([t, self.K]) for t in self.Nd]
        self.gammma = np.random.sample([self.M, self.K])
        self.lambbda = np.random.sample([self.K, self.V])

        
    def update_stochastic(self, max_iter, local_max_iter):
        
        self.T = []
        self.ELBO = []
        episron = 1e-3
        iterations = 1
        old_ELBO = 0

        while iterations < max_iter: 
    
            START = time.time()
            
            ##### update local parameters
            
            ## shuffle the samples
            shutffled_idx = range(self.M)
            np.random.shuffle(shutffled_idx)
            for rd_d in shutffled_idx:
                print rd_d
                nd_d = self.Nd[rd_d]
            
                # randomly initialize gamma for this gene
                # & give phi_local a strucutre
                gammma_local = np.random.sample(self.K)
                phi_local = np.zeros([rd_d, self.K])
            
                # optimize the local phi and gamma for this document
                local_iterations = 0
                while local_iterations < local_max_iter:
                
                    old_phi_local = self.phi[rd_d].copy()
                    old_gammma_local = self.gammma[rd_d].copy()
                
                    # update local phi
                    A = np.transpose(np.reshape(np.repeat(digamma(gammma_local), nd_d), [self.K, nd_d]))
                    B = np.dot(self.Wn[rd_d], digamma(np.transpose(self.lambbda)))
                    C = np.transpose(digamma(np.reshape(np.repeat(np.sum(np.transpose(self.lambbda), axis=0), nd_d), [self.K, nd_d]))) 
                
                    phi_local = A+B-C
                    phi_local = np.exp([x - max(x) for x in phi_local])
                    phi_local = np.array([x+1e-10 / sum(x+1e-10) for x in phi_local])
                              
                    # update local gamma 
                    gammma_local = np.sum(phi_local, axis=0) + self.alphii
                    if np.sum(np.linalg.norm(old_phi_local - phi_local) + np.linalg.norm(old_gammma_local - gammma_local)) < episron:
                        print 'Gene converged after %d iterations' % local_iterations
                        break
                    else:
                        self.phi[rd_d] = phi_local
                        self.gammma[rd_d] = gammma_local
                        local_iterations += 1
                                            
                assert ~np.isnan(np.sum(self.phi[rd_d]))
                assert np.sum(self.phi[rd_d] == 0) == 0
                assert ~np.isnan(np.sum(self.gammma[rd_d]))
                                
                    
            ##### update global parameters
            
            kappa = 0.55
            rhot = np.power(iterations + 1, kappa)
            
            ## update intermediate global parameter
            lambbda_med = np.zeros([self.K, self.V])
            for i in xrange(self.K):
                for j in xrange(self.V):
                    lambbda_med[i,j] = self.M * np.dot(self.Wn[rd_d][:,j], phi_local[:,i]) + self.etaj

            self.lambbda = (1-rhot) * self.lambbda  + rhot * lambbda_med
            assert ~np.isnan(np.sum(self.lambbda))


            ##### compute ELBO
            gammma_term = np.sum(np.array([gammaln(np.sum(t)) for t in self.gammma]) - np.sum([gammaln(t) for t in self.gammma],axis=1))
            lambda_term = np.sum(np.array([gammaln(np.sum(t)) for t in self.lambbda]) - np.sum([gammaln(t) for t in self.lambbda],axis=1))
            phi_term = np.sum([np.sum(t * np.log(t)) for t in self.phi])
            ELBO = -gammma_term - lambda_term - phi_term
            self.ELBO.append(ELBO)
            self.T.append(time.time() - START)
    
            print time.time() - START
            print gammma_term, lambda_term, phi_term, ELBO
    
            if np.abs(ELBO - old_ELBO) < episron:
                print 'Converged after %d iterations\n' % iterations
                break
            else:
                iterations += 1
                old_ELBO = ELBO.copy()

# %%
genes = LDA("Features.csv",4)
genes.update_stochastic(20,1000)
# Out:
# M = 190, V = 124, total number of words = 502401
# 165
# Gene converged after 24 iterations
# 74
# Gene converged after 44 iterations
# 22
# Gene converged after 53 iterations
# 82
# Gene converged after 32 iterations
# 54
# Gene converged after 22 iterations
# 112
# Gene converged after 44 iterations
# 139
# Gene converged after 55 iterations
# 35
# Gene converged after 27 iterations
# 129
# Gene converged after 72 iterations
# 71
# Gene converged after 35 iterations
# 119
# Gene converged after 65 iterations
# 157
# Gene converged after 24 iterations
# 130
# Gene converged after 44 iterations
# 93
# Gene converged after 46 iterations
# 49
# Gene converged after 34 iterations
# 169
# Gene converged after 29 iterations
# 60
# Gene converged after 50 iterations
# 92
# Gene converged after 49 iterations
# 164
# Gene converged after 37 iterations
# 76
# Gene converged after 35 iterations
# 156
# Gene converged after 38 iterations
# 127
# Gene converged after 38 iterations
# 88
# Gene converged after 54 iterations
# 75
# Gene converged after 59 iterations
# 30
# Gene converged after 42 iterations
# 116
# Gene converged after 38 iterations
# 151
# Gene converged after 41 iterations
# 182
# Gene converged after 39 iterations
# 183
# Gene converged after 71 iterations
# 163
# Gene converged after 30 iterations
# 44
# Gene converged after 30 iterations
# 59
# Gene converged after 48 iterations
# 117
# Gene converged after 20 iterations
# 103
# Gene converged after 29 iterations
# 110
# Gene converged after 48 iterations
# 179
# Gene converged after 35 iterations
# 12
# Gene converged after 37 iterations
# 145
# Gene converged after 28 iterations
# 122
# Gene converged after 26 iterations
# 85
# Gene converged after 37 iterations
# 140
# Gene converged after 19 iterations
# 177
# Gene converged after 39 iterations
# 113
# Gene converged after 35 iterations
# 159
# Gene converged after 36 iterations
# 66
# Gene converged after 23 iterations
# 73
# Gene converged after 31 iterations
# 184
# Gene converged after 52 iterations
# 87
# Gene converged after 45 iterations
# 52
# Gene converged after 25 iterations
# 187
# Gene converged after 55 iterations
# 154
# Gene converged after 19 iterations
# 80
# Gene converged after 36 iterations
# 162
# Gene converged after 39 iterations
# 123
# Gene converged after 32 iterations
# 94
# Gene converged after 32 iterations
# 9
# Gene converged after 51 iterations
# 79
# Gene converged after 46 iterations
# 121
# Gene converged after 23 iterations
# 174
# Gene converged after 30 iterations
# 142
# Gene converged after 18 iterations
# 148
# Gene converged after 24 iterations
# 5
# Gene converged after 73 iterations
# 84
# Gene converged after 44 iterations
# 81
# Gene converged after 50 iterations
# 40
# Gene converged after 18 iterations
# 168
# Gene converged after 31 iterations
# 39
# Gene converged after 33 iterations
# 53
# Gene converged after 42 iterations
# 167
# Gene converged after 32 iterations
# 58
# Gene converged after 26 iterations
# 102
# Gene converged after 48 iterations
# 126
# Gene converged after 59 iterations
# 15
# Gene converged after 43 iterations
# 46
# Gene converged after 63 iterations
# 38
# Gene converged after 34 iterations
# 21
# Gene converged after 69 iterations
# 77
# Gene converged after 25 iterations
# 143
# Gene converged after 34 iterations
# 10
# Gene converged after 42 iterations
# 34
# Gene converged after 41 iterations
# 97
# Gene converged after 23 iterations
# 25
# Gene converged after 41 iterations
# 14
# Gene converged after 40 iterations
# 185
# Gene converged after 16 iterations
# 150
# Gene converged after 50 iterations
# 55
# Gene converged after 30 iterations
# 133
# Gene converged after 54 iterations
# 149
# Gene converged after 54 iterations
# 124
# Gene converged after 37 iterations
# 91
# Gene converged after 28 iterations
# 104
# Gene converged after 32 iterations
# 111
# Gene converged after 35 iterations
# 13
# Gene converged after 39 iterations
# 166
# Gene converged after 44 iterations
# 1
# Gene converged after 34 iterations
# 171
# Gene converged after 44 iterations
# 29
# Gene converged after 41 iterations
# 101
# Gene converged after 38 iterations
# 96
# Gene converged after 37 iterations
# 125
# Gene converged after 23 iterations
# 189
# Gene converged after 44 iterations
# 11
# Gene converged after 55 iterations
# 41
# Gene converged after 35 iterations
# 146
# Gene converged after 49 iterations
# 64
# Gene converged after 46 iterations
# 178
# Gene converged after 41 iterations
# 128
# Gene converged after 20 iterations
# 152
# Gene converged after 44 iterations
# 109
# Gene converged after 91 iterations
# 67
# Gene converged after 29 iterations
# 131
# Gene converged after 40 iterations
# 153
# Gene converged after 46 iterations
# 136
# Gene converged after 66 iterations
# 70
# Gene converged after 40 iterations
# 31
# Gene converged after 47 iterations
# 50
# Gene converged after 54 iterations
# 181
# Gene converged after 39 iterations
# 27
# Gene converged after 55 iterations
# 16
# Gene converged after 30 iterations
# 6
# Gene converged after 73 iterations
# 78
# Gene converged after 29 iterations
# 69
# Gene converged after 26 iterations
# 57
# Gene converged after 74 iterations
# 180
# Gene converged after 45 iterations
# 135
# Gene converged after 22 iterations
# 56
# Gene converged after 49 iterations
# 155
# Gene converged after 27 iterations
# 89
# Gene converged after 40 iterations
# 161
# Gene converged after 35 iterations
# 26
# Gene converged after 31 iterations
# 175
# Gene converged after 40 iterations
# 107
# Gene converged after 45 iterations
# 8
# Gene converged after 36 iterations
# 106
# Gene converged after 40 iterations
# 72
# Gene converged after 44 iterations
# 83
# Gene converged after 30 iterations
# 160
# Gene converged after 42 iterations
# 24
# Gene converged after 44 iterations
# 65
# Gene converged after 46 iterations
# 186
# Gene converged after 54 iterations
# 158
# Gene converged after 42 iterations
# 120
# Gene converged after 38 iterations
# 108
# Gene converged after 29 iterations
# 114
# Gene converged after 51 iterations
# 61
# Gene converged after 39 iterations
# 2
# Gene converged after 38 iterations
# 147
# Gene converged after 49 iterations
# 170
# Gene converged after 33 iterations
# 68
# Gene converged after 44 iterations
# 43
# Gene converged after 42 iterations
# 3
# Gene converged after 30 iterations
# 19
# Gene converged after 45 iterations
# 132
# Gene converged after 36 iterations
# 33
# Gene converged after 39 iterations
# 23
# Gene converged after 40 iterations
# 134
# Gene converged after 49 iterations
# 63
# Gene converged after 48 iterations
# 7
# Gene converged after 26 iterations
# 17
# Gene converged after 18 iterations
# 100
# Gene converged after 63 iterations
# 4
# Gene converged after 42 iterations
# 105
# Gene converged after 42 iterations
# 0
# Gene converged after 44 iterations
# 118
# Gene converged after 33 iterations
# 51
# Gene converged after 44 iterations
# 37
# Gene converged after 46 iterations
# 141
# Gene converged after 39 iterations
# 45
# Gene converged after 30 iterations
# 99
# Gene converged after 28 iterations
# 20
# Gene converged after 41 iterations
# 137
# Gene converged after 66 iterations
# 176
# Gene converged after 37 iterations
# 144
# Gene converged after 29 iterations
# 138
# Gene converged after 45 iterations
# 28
# Gene converged after 48 iterations
# 188
# Gene converged after 42 iterations
# 115
# Gene converged after 61 iterations
# 86
# Gene converged after 58 iterations
# 48
# Gene converged after 33 iterations
# 18
# Gene converged after 40 iterations
# 172
# Gene converged after 22 iterations
# 36
# Gene converged after 47 iterations
# 32
# Gene converged after 52 iterations
# 47
# Gene converged after 46 iterations
# 90
# Gene converged after 35 iterations
# 62
# Gene converged after 39 iterations
# 173
# Gene converged after 48 iterations
# 42
# Gene converged after 38 iterations
# 95
# Gene converged after 46 iterations
# 98
# Gene converged after 48 iterations
# 219.159083843
# 1132441.06124 2286848.31224 -267819.075302 -3151470.29818
# 62
# Gene converged after 34 iterations
# 142
# Gene converged after 19 iterations
# 158
# Gene converged after 32 iterations
# 147
# Gene converged after 23 iterations
# 132
# Gene converged after 42 iterations
# 107
# Gene converged after 34 iterations
# 3
# Gene converged after 56 iterations
# 7
# Gene converged after 37 iterations
# 90
# Gene converged after 33 iterations
# 20
# Gene converged after 39 iterations
# 85
# Gene converged after 46 iterations
# 67
# Gene converged after 24 iterations
# 37
# Gene converged after 28 iterations
# 57
# Gene converged after 38 iterations
# 64
# Gene converged after 20 iterations
# 144
# Gene converged after 21 iterations
# 150
# Gene converged after 34 iterations
# 87
# Gene converged after 28 iterations
# 157
# Gene converged after 24 iterations
# 49
# Gene converged after 22 iterations
# 138
# Gene converged after 29 iterations
# 177
# Gene converged after 22 iterations
# 96
# Gene converged after 25 iterations
# 26
# Gene converged after 21 iterations
# 45
# Gene converged after 35 iterations
# 127
# Gene converged after 34 iterations
# 50
# Gene converged after 23 iterations
# 35
# Gene converged after 29 iterations
# 182
# Gene converged after 26 iterations
# 123
# Gene converged after 26 iterations
# 34
# Gene converged after 51 iterations
# 47
# Gene converged after 33 iterations
# 72
# Gene converged after 43 iterations
# 135
# Gene converged after 33 iterations
# 145
# Gene converged after 29 iterations
# 54
# Gene converged after 28 iterations
# 76
# Gene converged after 26 iterations
# 133
# Gene converged after 36 iterations
# 139
# Gene converged after 31 iterations
# 154
# Gene converged after 29 iterations
# 6
# Gene converged after 30 iterations
# 169
# Gene converged after 23 iterations
# 95
# Gene converged after 31 iterations
# 162
# Gene converged after 76 iterations
# 82
# Gene converged after 31 iterations
# 33
# Gene converged after 40 iterations
# 159
# Gene converged after 29 iterations
# 0
# Gene converged after 26 iterations
# 77
# Gene converged after 25 iterations
# 119
# Gene converged after 30 iterations
# 84
# Gene converged after 44 iterations
# 97
# Gene converged after 45 iterations
# 117
# Gene converged after 47 iterations
# 171
# Gene converged after 29 iterations
# 98
# Gene converged after 36 iterations
# 29
# Gene converged after 26 iterations
# 114
# Gene converged after 26 iterations
# 93
# Gene converged after 34 iterations
# 102
# Gene converged after 30 iterations
# 168
# Gene converged after 23 iterations
# 167
# Gene converged after 32 iterations
# 4
# Gene converged after 40 iterations
# 23
# Gene converged after 31 iterations
# 10
# Gene converged after 44 iterations
# 43
# Gene converged after 35 iterations
# 108
# Gene converged after 21 iterations
# 73
# Gene converged after 18 iterations
# 19
# Gene converged after 43 iterations
# 170
# Gene converged after 31 iterations
# 24
# Gene converged after 29 iterations
# 36
# Gene converged after 31 iterations
# 15
# Gene converged after 29 iterations
# 122
# Gene converged after 25 iterations
# 134
# Gene converged after 27 iterations
# 152
# Gene converged after 37 iterations
# 185
# Gene converged after 32 iterations
# 99
# Gene converged after 18 iterations
# 74
# Gene converged after 45 iterations
# 30
# Gene converged after 42 iterations
# 161
# Gene converged after 25 iterations
# 149
# Gene converged after 19 iterations
# 176
# Gene converged after 22 iterations
# 175
# Gene converged after 23 iterations
# 46
# Gene converged after 38 iterations
# 148
# Gene converged after 31 iterations
# 111
# Gene converged after 37 iterations
# 25
# Gene converged after 32 iterations
# 151
# Gene converged after 31 iterations
# 110
# Gene converged after 34 iterations
# 27
# Gene converged after 32 iterations
# 9
# Gene converged after 28 iterations
# 75
# Gene converged after 40 iterations
# 91
# Gene converged after 13 iterations
# 28
# Gene converged after 28 iterations
# 52
# Gene converged after 22 iterations
# 181
# Gene converged after 36 iterations
# 183
# Gene converged after 44 iterations
# 55
# Gene converged after 25 iterations
# 65
# Gene converged after 32 iterations
# 18
# Gene converged after 38 iterations
# 92
# Gene converged after 21 iterations
# 22
# Gene converged after 21 iterations
# 164
# Gene converged after 31 iterations
# 58
# Gene converged after 35 iterations
# 174
# Gene converged after 27 iterations
# 126
# Gene converged after 23 iterations
# 155
# Gene converged after 24 iterations
# 188
# Gene converged after 35 iterations
# 21
# Gene converged after 30 iterations
# 79
# Gene converged after 38 iterations
# 17
# Gene converged after 18 iterations
# 81
# Gene converged after 20 iterations
# 173
# Gene converged after 24 iterations
# 51
# Gene converged after 27 iterations
# 53
# Gene converged after 51 iterations
# 59
# Gene converged after 37 iterations
# 66
# Gene converged after 26 iterations
# 131
# Gene converged after 26 iterations
# 179
# Gene converged after 30 iterations
# 78
# Gene converged after 39 iterations
# 129
# Gene converged after 24 iterations
# 120
# Gene converged after 41 iterations
# 70
# Gene converged after 28 iterations
# 103
# Gene converged after 35 iterations
# 104
# Gene converged after 22 iterations
# 14
# Gene converged after 23 iterations
# 136
# Gene converged after 37 iterations
# 106
# Gene converged after 18 iterations
# 89
# Gene converged after 29 iterations
# 86
# Gene converged after 22 iterations
# 101
# Gene converged after 41 iterations
# 44
# Gene converged after 33 iterations
# 16
# Gene converged after 30 iterations
# 56
# Gene converged after 27 iterations
# 118
# Gene converged after 34 iterations
# 141
# Gene converged after 52 iterations
# 165
# Gene converged after 28 iterations
# 68
# Gene converged after 23 iterations
# 38
# Gene converged after 36 iterations
# 5
# Gene converged after 20 iterations
# 48
# Gene converged after 43 iterations
# 121
# Gene converged after 28 iterations
# 189
# Gene converged after 38 iterations
# 130
# Gene converged after 24 iterations
# 116
# Gene converged after 20 iterations
# 13
# Gene converged after 20 iterations
# 69
# Gene converged after 26 iterations
# 146
# Gene converged after 25 iterations
# 100
# Gene converged after 51 iterations
# 83
# Gene converged after 35 iterations
# 163
# Gene converged after 11 iterations
# 160
# Gene converged after 30 iterations
# 63
# Gene converged after 23 iterations
# 109
# Gene converged after 60 iterations
# 125
# Gene converged after 22 iterations
# 1
# Gene converged after 23 iterations
# 71
# Gene converged after 37 iterations
# 88
# Gene converged after 37 iterations
# 137
# Gene converged after 21 iterations
# 61
# Gene converged after 30 iterations
# 128
# Gene converged after 22 iterations
# 156
# Gene converged after 39 iterations
# 115
# Gene converged after 22 iterations
# 178
# Gene converged after 24 iterations
# 41
# Gene converged after 27 iterations
# 39
# Gene converged after 41 iterations
# 2
# Gene converged after 26 iterations
# 40
# Gene converged after 72 iterations
# 143
# Gene converged after 43 iterations
# 11
# Gene converged after 20 iterations
# 12
# Gene converged after 23 iterations
# 153
# Gene converged after 36 iterations
# 180
# Gene converged after 65 iterations
# 166
# Gene converged after 37 iterations
# 60
# Gene converged after 22 iterations
# 94
# Gene converged after 22 iterations
# 42
# Gene converged after 33 iterations
# 140
# Gene converged after 33 iterations
# 184
# Gene converged after 31 iterations
# 32
# Gene converged after 29 iterations
# 105
# Gene converged after 43 iterations
# 187
# Gene converged after 31 iterations
# 31
# Gene converged after 34 iterations
# 80
# Gene converged after 23 iterations
# 112
# Gene converged after 41 iterations
# 113
# Gene converged after 23 iterations
# 186
# Gene converged after 30 iterations
# 124
# Gene converged after 44 iterations
# 172
# Gene converged after 32 iterations
# 8
# Gene converged after 28 iterations
# 183.259838104
# 1031460.28075 -790355.888954 -203758.46162 -37345.9301812
# 185
# Gene converged after 7 iterations
# 165
# Gene converged after 9 iterations
# 160
# Gene converged after 11 iterations
# 112
# Gene converged after 8 iterations
# 52
# Gene converged after 8 iterations
# 49
# Gene converged after 10 iterations
# 27
# Gene converged after 9 iterations
# 80
# Gene converged after 6 iterations
# 47
# Gene converged after 7 iterations
# 81
# Gene converged after 8 iterations
# 164
# Gene converged after 6 iterations
# 101
# Gene converged after 14 iterations
# 37
# Gene converged after 7 iterations
# 48
# Gene converged after 8 iterations
# 100
# Gene converged after 7 iterations
# 102
# Gene converged after 10 iterations
# 19
# Gene converged after 15 iterations
# 7
# Gene converged after 15 iterations
# 182
# Gene converged after 9 iterations
# 135
# Gene converged after 7 iterations
# 140
# Gene converged after 7 iterations
# 136
# Gene converged after 8 iterations
# 150
# Gene converged after 11 iterations
# 51
# Gene converged after 7 iterations
# 3
# Gene converged after 16 iterations
# 152
# Gene converged after 7 iterations
# 70
# Gene converged after 6 iterations
# 153
# Gene converged after 7 iterations
# 42
# Gene converged after 8 iterations
# 123
# Gene converged after 8 iterations
# 17
# Gene converged after 20 iterations
# 187
# Gene converged after 13 iterations
# 8
# Gene converged after 8 iterations
# 89
# Gene converged after 8 iterations
# 83
# Gene converged after 8 iterations
# 115
# Gene converged after 13 iterations
# 4
# Gene converged after 6 iterations
# 34
# Gene converged after 17 iterations
# 40
# Gene converged after 18 iterations
# 168
# Gene converged after 8 iterations
# 44
# Gene converged after 7 iterations
# 9
# Gene converged after 8 iterations
# 109
# Gene converged after 7 iterations
# 170
# Gene converged after 9 iterations
# 129
# Gene converged after 10 iterations
# 57
# Gene converged after 7 iterations
# 96
# Gene converged after 6 iterations
# 175
# Gene converged after 9 iterations
# 108
# Gene converged after 9 iterations
# 68
# Gene converged after 9 iterations
# 173
# Gene converged after 8 iterations
# 41
# Gene converged after 8 iterations
# 31
# Gene converged after 7 iterations
# 154
# Gene converged after 9 iterations
# 155
# Gene converged after 6 iterations
# 59
# Gene converged after 7 iterations
# 93
# Gene converged after 7 iterations
# 15
# Gene converged after 10 iterations
# 77
# Gene converged after 8 iterations
# 75
# Gene converged after 9 iterations
# 105
# Gene converged after 13 iterations
# 78
# Gene converged after 8 iterations
# 5
# Gene converged after 7 iterations
# 10
# Gene converged after 8 iterations
# 16
# Gene converged after 6 iterations
# 181
# Gene converged after 10 iterations
# 104
# Gene converged after 7 iterations
# 149
# Gene converged after 7 iterations
# 148
# Gene converged after 10 iterations
# 118
# Gene converged after 9 iterations
# 26
# Gene converged after 6 iterations
# 107
# Gene converged after 8 iterations
# 65
# Gene converged after 13 iterations
# 2
# Gene converged after 9 iterations
# 171
# Gene converged after 8 iterations
# 1
# Gene converged after 5 iterations
# 22
# Gene converged after 8 iterations
# 110
# Gene converged after 12 iterations
# 35
# Gene converged after 6 iterations
# 145
# Gene converged after 13 iterations
# 159
# Gene converged after 9 iterations
# 142
# Gene converged after 8 iterations
# 24
# Gene converged after 8 iterations
# 85
# Gene converged after 9 iterations
# 113
# Gene converged after 12 iterations
# 55
# Gene converged after 9 iterations
# 39
# Gene converged after 7 iterations
# 124
# Gene converged after 10 iterations
# 99
# Gene converged after 7 iterations
# 151
# Gene converged after 10 iterations
# 43
# Gene converged after 6 iterations
# 137
# Gene converged after 7 iterations
# 111
# Gene converged after 10 iterations
# 94
# Gene converged after 7 iterations
# 50
# Gene converged after 9 iterations
# 146
# Gene converged after 8 iterations
# 97
# Gene converged after 7 iterations
# 130
# Gene converged after 7 iterations
# 25
# Gene converged after 8 iterations
# 169
# Gene converged after 7 iterations
# 30
# Gene converged after 10 iterations
# 157
# Gene converged after 10 iterations
# 76
# Gene converged after 9 iterations
# 33
# Gene converged after 8 iterations
# 38
# Gene converged after 12 iterations
# 32
# Gene converged after 6 iterations
# 54
# Gene converged after 8 iterations
# 12
# Gene converged after 10 iterations
# 74
# Gene converged after 6 iterations
# 79
# Gene converged after 8 iterations
# 46
# Gene converged after 10 iterations
# 28
# Gene converged after 6 iterations
# 92
# Gene converged after 7 iterations
# 161
# Gene converged after 8 iterations
# 162
# Gene converged after 7 iterations
# 131
# Gene converged after 11 iterations
# 144
# Gene converged after 10 iterations
# 106
# Gene converged after 8 iterations
# 82
# Gene converged after 9 iterations
# 11
# Gene converged after 10 iterations
# 91
# Gene converged after 12 iterations
# 21
# Gene converged after 7 iterations
# 58
# Gene converged after 9 iterations
# 63
# Gene converged after 7 iterations
# 179
# Gene converged after 9 iterations
# 163
# Gene converged after 6 iterations
# 90
# Gene converged after 9 iterations
# 189
# Gene converged after 10 iterations
# 177
# Gene converged after 9 iterations
# 23
# Gene converged after 7 iterations
# 147
# Gene converged after 9 iterations
# 141
# Gene converged after 14 iterations
# 120
# Gene converged after 10 iterations
# 158
# Gene converged after 9 iterations
# 103
# Gene converged after 7 iterations
# 84
# Gene converged after 8 iterations
# 95
# Gene converged after 8 iterations
# 132
# Gene converged after 8 iterations
# 6
# Gene converged after 8 iterations
# 128
# Gene converged after 8 iterations
# 18
# Gene converged after 10 iterations
# 143
# Gene converged after 7 iterations
# 71
# Gene converged after 6 iterations
# 56
# Gene converged after 9 iterations
# 14
# Gene converged after 7 iterations
# 166
# Gene converged after 10 iterations
# 121
# Gene converged after 7 iterations
# 60
# Gene converged after 6 iterations
# 122
# Gene converged after 12 iterations
# 36
# Gene converged after 12 iterations
# 88
# Gene converged after 8 iterations
# 180
# Gene converged after 11 iterations
# 67
# Gene converged after 6 iterations
# 64
# Gene converged after 8 iterations
# 126
# Gene converged after 7 iterations
# 133
# Gene converged after 7 iterations
# 73
# Gene converged after 6 iterations
# 183
# Gene converged after 11 iterations
# 174
# Gene converged after 11 iterations
# 45
# Gene converged after 7 iterations
# 176
# Gene converged after 7 iterations
# 61
# Gene converged after 8 iterations
# 188
# Gene converged after 9 iterations
# 134
# Gene converged after 9 iterations
# 178
# Gene converged after 7 iterations
# 172
# Gene converged after 8 iterations
# 117
# Gene converged after 10 iterations
# 156
# Gene converged after 6 iterations
# 98
# Gene converged after 12 iterations
# 20
# Gene converged after 10 iterations
# 186
# Gene converged after 11 iterations
# 13
# Gene converged after 6 iterations
# 167
# Gene converged after 9 iterations
# 139
# Gene converged after 10 iterations
# 0
# Gene converged after 5 iterations
# 127
# Gene converged after 7 iterations
# 86
# Gene converged after 10 iterations
# 62
# Gene converged after 8 iterations
# 66
# Gene converged after 6 iterations
# 116
# Gene converged after 10 iterations
# 114
# Gene converged after 7 iterations
# 69
# Gene converged after 7 iterations
# 87
# Gene converged after 7 iterations
# 125
# Gene converged after 8 iterations
# 138
# Gene converged after 7 iterations
# 29
# Gene converged after 7 iterations
# 119
# Gene converged after 8 iterations
# 53
# Gene converged after 6 iterations
# 184
# Gene converged after 8 iterations
# 72
# Gene converged after 10 iterations
# 55.6438388824
# 463020.363831 5763558.26742 -25287.9669937 -6201290.66426
# 185
# Gene converged after 17 iterations
# 164
# Gene converged after 22 iterations
# 105
# Gene converged after 21 iterations
# 139
# Gene converged after 23 iterations
# 91
# Gene converged after 15 iterations
# 14
# Gene converged after 24 iterations
# 119
# Gene converged after 21 iterations
# 188
# Gene converged after 20 iterations
# 5
# Gene converged after 14 iterations
# 103
# Gene converged after 21 iterations
# 109
# Gene converged after 24 iterations
# 48
# Gene converged after 17 iterations
# 94
# Gene converged after 21 iterations
# 28
# Gene converged after 20 iterations
# 101
# Gene converged after 19 iterations
# 44
# Gene converged after 23 iterations
# 163
# Gene converged after 30 iterations
# 45
# Gene converged after 21 iterations
# 138
# Gene converged after 24 iterations
# 3
# Gene converged after 24 iterations
# 2
# Gene converged after 19 iterations
# 20
# Gene converged after 20 iterations
# 66
# Gene converged after 13 iterations
# 39
# Gene converged after 15 iterations
# 31
# Gene converged after 21 iterations
# 104
# Gene converged after 19 iterations
# 186
# Gene converged after 25 iterations
# 100
# Gene converged after 20 iterations
# 32
# Gene converged after 25 iterations
# 56
# Gene converged after 21 iterations
# 137
# Gene converged after 17 iterations
# 26
# Gene converged after 18 iterations
# 22
# Gene converged after 18 iterations
# 124
# Gene converged after 24 iterations
# 87
# Gene converged after 21 iterations
# 12
# Gene converged after 18 iterations
# 177
# Gene converged after 19 iterations
# 38
# Gene converged after 22 iterations
# 182
# Gene converged after 21 iterations
# 49
# Gene converged after 18 iterations
# 127
# Gene converged after 17 iterations
# 36
# Gene converged after 22 iterations
# 29
# Gene converged after 17 iterations
# 34
# Gene converged after 20 iterations
# 11
# Gene converged after 18 iterations
# 61
# Gene converged after 20 iterations
# 86
# Gene converged after 15 iterations
# 73
# Gene converged after 16 iterations
# 42
# Gene converged after 19 iterations
# 96
# Gene converged after 19 iterations
# 147
# Gene converged after 18 iterations
# 128
# Gene converged after 24 iterations
# 43
# Gene converged after 22 iterations
# 106
# Gene converged after 16 iterations
# 118
# Gene converged after 18 iterations
# 83
# Gene converged after 21 iterations
# 176
# Gene converged after 23 iterations
# 175
# Gene converged after 20 iterations
# 134
# Gene converged after 15 iterations
# 4
# Gene converged after 19 iterations
# 17
# Gene converged after 25 iterations
# 69
# Gene converged after 19 iterations
# 135
# Gene converged after 19 iterations
# 169
# Gene converged after 17 iterations
# 107
# Gene converged after 21 iterations
# 21
# Gene converged after 17 iterations
# 72
# Gene converged after 18 iterations
# 121
# Gene converged after 16 iterations
# 85
# Gene converged after 20 iterations
# 117
# Gene converged after 18 iterations
# 10
# Gene converged after 20 iterations
# 27
# Gene converged after 18 iterations
# 159
# Gene converged after 21 iterations
# 78
# Gene converged after 17 iterations
# 160
# Gene converged after 22 iterations
# 125
# Gene converged after 18 iterations
# 33
# Gene converged after 19 iterations
# 173
# Gene converged after 27 iterations
# 15
# Gene converged after 17 iterations
# 19
# Gene converged after 18 iterations
# 178
# Gene converged after 18 iterations
# 156
# Gene converged after 20 iterations
# 151
# Gene converged after 22 iterations
# 50
# Gene converged after 18 iterations
# 88
# Gene converged after 22 iterations
# 76
# Gene converged after 17 iterations
# 116
# Gene converged after 21 iterations
# 35
# Gene converged after 14 iterations
# 189
# Gene converged after 24 iterations
# 77
# Gene converged after 20 iterations
# 122
# Gene converged after 17 iterations
# 90
# Gene converged after 19 iterations
# 13
# Gene converged after 18 iterations
# 37
# Gene converged after 23 iterations
# 187
# Gene converged after 28 iterations
# 162
# Gene converged after 19 iterations
# 23
# Gene converged after 20 iterations
# 112
# Gene converged after 21 iterations
# 172
# Gene converged after 19 iterations
# 115
# Gene converged after 15 iterations
# 171
# Gene converged after 18 iterations
# 184
# Gene converged after 22 iterations
# 141
# Gene converged after 20 iterations
# 82
# Gene converged after 20 iterations
# 167
# Gene converged after 17 iterations
# 8
# Gene converged after 20 iterations
# 166
# Gene converged after 20 iterations
# 161
# Gene converged after 21 iterations
# 68
# Gene converged after 21 iterations
# 81
# Gene converged after 25 iterations
# 93
# Gene converged after 21 iterations
# 67
# Gene converged after 15 iterations
# 97
# Gene converged after 20 iterations
# 53
# Gene converged after 24 iterations
# 136
# Gene converged after 18 iterations
# 1
# Gene converged after 14 iterations
# 95
# Gene converged after 21 iterations
# 180
# Gene converged after 28 iterations
# 179
# Gene converged after 22 iterations
# 150
# Gene converged after 19 iterations
# 144
# Gene converged after 23 iterations
# 140
# Gene converged after 22 iterations
# 57
# Gene converged after 33 iterations
# 110
# Gene converged after 19 iterations
# 168
# Gene converged after 20 iterations
# 40
# Gene converged after 20 iterations
# 133
# Gene converged after 23 iterations
# 65
# Gene converged after 23 iterations
# 84
# Gene converged after 23 iterations
# 120
# Gene converged after 18 iterations
# 0
# Gene converged after 18 iterations
# 157
# Gene converged after 23 iterations
# 30
# Gene converged after 22 iterations
# 63
# Gene converged after 15 iterations
# 146
# Gene converged after 20 iterations
# 60
# Gene converged after 17 iterations
# 7
# Gene converged after 17 iterations
# 75
# Gene converged after 18 iterations
# 9
# Gene converged after 23 iterations
# 62
# Gene converged after 21 iterations
# 99
# Gene converged after 25 iterations
# 41
# Gene converged after 22 iterations
# 148
# Gene converged after 22 iterations
# 158
# Gene converged after 20 iterations
# 47
# Gene converged after 24 iterations
# 153
# Gene converged after 19 iterations
# 51
# Gene converged after 17 iterations
# 142
# Gene converged after 20 iterations
# 131
# Gene converged after 21 iterations
# 52
# Gene converged after 21 iterations
# 114
# Gene converged after 22 iterations
# 64
# Gene converged after 21 iterations
# 165
# Gene converged after 20 iterations
# 25
# Gene converged after 22 iterations
# 55
# Gene converged after 16 iterations
# 16
# Gene converged after 15 iterations
# 130
# Gene converged after 17 iterations
# 174
# Gene converged after 23 iterations
# 145
# Gene converged after 20 iterations
# 155
# Gene converged after 19 iterations
# 181
# Gene converged after 21 iterations
# 80
# Gene converged after 20 iterations
# 102
# Gene converged after 23 iterations
# 143
# Gene converged after 18 iterations
# 108
# Gene converged after 17 iterations
# 183
# Gene converged after 20 iterations
# 123
# Gene converged after 17 iterations
# 70
# Gene converged after 21 iterations
# 152
# Gene converged after 24 iterations
# 129
# Gene converged after 25 iterations
# 59
# Gene converged after 21 iterations
# 74
# Gene converged after 19 iterations
# 24
# Gene converged after 20 iterations
# 111
# Gene converged after 19 iterations
# 132
# Gene converged after 17 iterations
# 92
# Gene converged after 23 iterations
# 18
# Gene converged after 19 iterations
# 126
# Gene converged after 23 iterations
# 46
# Gene converged after 19 iterations
# 154
# Gene converged after 27 iterations
# 98
# Gene converged after 40 iterations
# 54
# Gene converged after 22 iterations
# 89
# Gene converged after 20 iterations
# 71
# Gene converged after 20 iterations
# 58
# Gene converged after 20 iterations
# 6
# Gene converged after 23 iterations
# 170
# Gene converged after 25 iterations
# 149
# Gene converged after 22 iterations
# 113
# Gene converged after 14 iterations
# 79
# Gene converged after 19 iterations
# 119.233978987
# 798641.08523 648890.865623 -149427.982509 -1298103.96834
# 153
# Gene converged after 15 iterations
# 156
# Gene converged after 26 iterations
# 178
# Gene converged after 12 iterations
# 171
# Gene converged after 13 iterations
# 73
# Gene converged after 18 iterations
# 169
# Gene converged after 15 iterations
# 158
# Gene converged after 15 iterations
# 124
# Gene converged after 13 iterations
# 53
# Gene converged after 13 iterations
# 66
# Gene converged after 13 iterations
# 75
# Gene converged after 15 iterations
# 6
# Gene converged after 14 iterations
# 38
# Gene converged after 15 iterations
# 187
# Gene converged after 14 iterations
# 64
# Gene converged after 13 iterations
# 122
# Gene converged after 16 iterations
# 89
# Gene converged after 17 iterations
# 115
# Gene converged after 17 iterations
# 83
# Gene converged after 21 iterations
# 118
# Gene converged after 12 iterations
# 55
# Gene converged after 15 iterations
# 107
# Gene converged after 12 iterations
# 151
# Gene converged after 14 iterations
# 74
# Gene converged after 16 iterations
# 112
# Gene converged after 15 iterations
# 117
# Gene converged after 12 iterations
# 70
# Gene converged after 15 iterations
# 123
# Gene converged after 16 iterations
# 27
# Gene converged after 13 iterations
# 67
# Gene converged after 13 iterations
# 86
# Gene converged after 11 iterations
# 120
# Gene converged after 16 iterations
# 154
# Gene converged after 21 iterations
# 22
# Gene converged after 11 iterations
# 138
# Gene converged after 14 iterations
# 92
# Gene converged after 14 iterations
# 46
# Gene converged after 20 iterations
# 146
# Gene converged after 16 iterations
# 110
# Gene converged after 10 iterations
# 98
# Gene converged after 11 iterations
# 8
# Gene converged after 10 iterations
# 51
# Gene converged after 15 iterations
# 28
# Gene converged after 12 iterations
# 121
# Gene converged after 16 iterations
# 85
# Gene converged after 11 iterations
# 40
# Gene converged after 16 iterations
# 47
# Gene converged after 13 iterations
# 79
# Gene converged after 13 iterations
# 113
# Gene converged after 18 iterations
# 183
# Gene converged after 11 iterations
# 173
# Gene converged after 15 iterations
# 116
# Gene converged after 13 iterations
# 126
# Gene converged after 13 iterations
# 80
# Gene converged after 17 iterations
# 100
# Gene converged after 16 iterations
# 71
# Gene converged after 14 iterations
# 91
# Gene converged after 13 iterations
# 139
# Gene converged after 16 iterations
# 23
# Gene converged after 14 iterations
# 142
# Gene converged after 19 iterations
# 43
# Gene converged after 23 iterations
# 111
# Gene converged after 17 iterations
# 135
# Gene converged after 12 iterations
# 68
# Gene converged after 13 iterations
# 69
# Gene converged after 14 iterations
# 42
# Gene converged after 16 iterations
# 179
# Gene converged after 14 iterations
# 131
# Gene converged after 13 iterations
# 31
# Gene converged after 13 iterations
# 140
# Gene converged after 14 iterations
# 186
# Gene converged after 14 iterations
# 33
# Gene converged after 13 iterations
# 101
# Gene converged after 15 iterations
# 62
# Gene converged after 16 iterations
# 141
# Gene converged after 13 iterations
# 170
# Gene converged after 13 iterations
# 94
# Gene converged after 21 iterations
# 145
# Gene converged after 13 iterations
# 34
# Gene converged after 12 iterations
# 76
# Gene converged after 9 iterations
# 0
# Gene converged after 17 iterations
# 36
# Gene converged after 13 iterations
# 180
# Gene converged after 19 iterations
# 150
# Gene converged after 15 iterations
# 65
# Gene converged after 15 iterations
# 84
# Gene converged after 13 iterations
# 30
# Gene converged after 14 iterations
# 176
# Gene converged after 14 iterations
# 134
# Gene converged after 15 iterations
# 35
# Gene converged after 16 iterations
# 11
# Gene converged after 13 iterations
# 52
# Gene converged after 16 iterations
# 39
# Gene converged after 31 iterations
# 167
# Gene converged after 16 iterations
# 132
# Gene converged after 19 iterations
# 57
# Gene converged after 12 iterations
# 12
# Gene converged after 15 iterations
# 87
# Gene converged after 14 iterations
# 1
# Gene converged after 18 iterations
# 59
# Gene converged after 10 iterations
# 97
# Gene converged after 17 iterations
# 7
# Gene converged after 10 iterations
# 174
# Gene converged after 13 iterations
# 184
# Gene converged after 16 iterations
# 26
# Gene converged after 15 iterations
# 24
# Gene converged after 11 iterations
# 14
# Gene converged after 14 iterations
# 44
# Gene converged after 13 iterations
# 41
# Gene converged after 13 iterations
# 166
# Gene converged after 12 iterations
# 5
# Gene converged after 11 iterations
# 13
# Gene converged after 21 iterations
# 81
# Gene converged after 14 iterations
# 181
# Gene converged after 18 iterations
# 106
# Gene converged after 13 iterations
# 88
# Gene converged after 13 iterations
# 144
# Gene converged after 14 iterations
# 56
# Gene converged after 14 iterations
# 17
# Gene converged after 17 iterations
# 114
# Gene converged after 12 iterations
# 185
# Gene converged after 15 iterations
# 18
# Gene converged after 14 iterations
# 3
# Gene converged after 13 iterations
# 82
# Gene converged after 15 iterations
# 63
# Gene converged after 12 iterations
# 72
# Gene converged after 15 iterations
# 168
# Gene converged after 11 iterations
# 54
# Gene converged after 13 iterations
# 78
# Gene converged after 10 iterations
# 177
# Gene converged after 13 iterations
# 10
# Gene converged after 14 iterations
# 20
# Gene converged after 12 iterations
# 19
# Gene converged after 11 iterations
# 50
# Gene converged after 20 iterations
# 96
# Gene converged after 18 iterations
# 159
# Gene converged after 14 iterations
# 162
# Gene converged after 12 iterations
# 93
# Gene converged after 15 iterations
# 147
# Gene converged after 13 iterations
# 58
# Gene converged after 14 iterations
# 133
# Gene converged after 14 iterations
# 182
# Gene converged after 14 iterations
# 136
# Gene converged after 15 iterations
# 9
# Gene converged after 15 iterations
# 164
# Gene converged after 15 iterations
# 25
# Gene converged after 13 iterations
# 160
# Gene converged after 16 iterations
# 15
# Gene converged after 12 iterations
# 172
# Gene converged after 16 iterations
# 161
# Gene converged after 14 iterations
# 130
# Gene converged after 16 iterations
# 128
# Gene converged after 17 iterations
# 60
# Gene converged after 15 iterations
# 16
# Gene converged after 15 iterations
# 143
# Gene converged after 14 iterations
# 99
# Gene converged after 17 iterations
# 109
# Gene converged after 15 iterations
# 37
# Gene converged after 18 iterations
# 103
# Gene converged after 12 iterations
# 32
# Gene converged after 15 iterations
# 49
# Gene converged after 16 iterations
# 127
# Gene converged after 13 iterations
# 125
# Gene converged after 13 iterations
# 90
# Gene converged after 16 iterations
# 149
# Gene converged after 24 iterations
# 95
# Gene converged after 15 iterations
# 152
# Gene converged after 12 iterations
# 102
# Gene converged after 12 iterations
# 165
# Gene converged after 12 iterations
# 21
# Gene converged after 14 iterations
# 2
# Gene converged after 19 iterations
# 29
# Gene converged after 21 iterations
# 175
# Gene converged after 17 iterations
# 155
# Gene converged after 14 iterations
# 48
# Gene converged after 15 iterations
# 119
# Gene converged after 10 iterations
# 104
# Gene converged after 14 iterations
# 188
# Gene converged after 11 iterations
# 61
# Gene converged after 15 iterations
# 148
# Gene converged after 14 iterations
# 4
# Gene converged after 13 iterations
# 137
# Gene converged after 16 iterations
# 189
# Gene converged after 18 iterations
# 157
# Gene converged after 15 iterations
# 108
# Gene converged after 17 iterations
# 77
# Gene converged after 15 iterations
# 105
# Gene converged after 14 iterations
# 163
# Gene converged after 14 iterations
# 129
# Gene converged after 13 iterations
# 45
# Gene converged after 12 iterations
# 82.4291241169
# 631009.68321 1574376.65069 -68625.9196137 -2136760.41429
# 22
# Gene converged after 13 iterations
# 129
# Gene converged after 21 iterations
# 150
# Gene converged after 19 iterations
# 74
# Gene converged after 16 iterations
# 159
# Gene converged after 20 iterations
# 183
# Gene converged after 20 iterations
# 189
# Gene converged after 25 iterations
# 174
# Gene converged after 18 iterations
# 146
# Gene converged after 14 iterations
# 102
# Gene converged after 19 iterations
# 28
# Gene converged after 19 iterations
# 163
# Gene converged after 3 iterations
# 13
# Gene converged after 31 iterations
# 109
# Gene converged after 18 iterations
# 122
# Gene converged after 16 iterations
# 58
# Gene converged after 15 iterations
# 57
# Gene converged after 17 iterations
# 176
# Gene converged after 14 iterations
# 170
# Gene converged after 30 iterations
# 73
# Gene converged after 16 iterations
# 162
# Gene converged after 15 iterations
# 47
# Gene converged after 14 iterations
# 40
# Gene converged after 18 iterations
# 3
# Gene converged after 19 iterations
# 87
# Gene converged after 14 iterations
# 12
# Gene converged after 20 iterations
# 52
# Gene converged after 22 iterations
# 24
# Gene converged after 15 iterations
# 116
# Gene converged after 20 iterations
# 16
# Gene converged after 15 iterations
# 20
# Gene converged after 21 iterations
# 158
# Gene converged after 17 iterations
# 10
# Gene converged after 16 iterations
# 18
# Gene converged after 15 iterations
# 133
# Gene converged after 22 iterations
# 75
# Gene converged after 15 iterations
# 80
# Gene converged after 16 iterations
# 177
# Gene converged after 18 iterations
# 132
# Gene converged after 16 iterations
# 168
# Gene converged after 14 iterations
# 155
# Gene converged after 22 iterations
# 96
# Gene converged after 12 iterations
# 51
# Gene converged after 17 iterations
# 181
# Gene converged after 17 iterations
# 81
# Gene converged after 8 iterations
# 151
# Gene converged after 22 iterations
# 11
# Gene converged after 20 iterations
# 100
# Gene converged after 13 iterations
# 63
# Gene converged after 16 iterations
# 67
# Gene converged after 16 iterations
# 14
# Gene converged after 18 iterations
# 93
# Gene converged after 23 iterations
# 84
# Gene converged after 23 iterations
# 152
# Gene converged after 12 iterations
# 62
# Gene converged after 19 iterations
# 1
# Gene converged after 13 iterations
# 107
# Gene converged after 22 iterations
# 38
# Gene converged after 22 iterations
# 71
# Gene converged after 15 iterations
# 32
# Gene converged after 17 iterations
# 131
# Gene converged after 23 iterations
# 111
# Gene converged after 11 iterations
# 49
# Gene converged after 16 iterations
# 136
# Gene converged after 16 iterations
# 9
# Gene converged after 22 iterations
# 114
# Gene converged after 25 iterations
# 180
# Gene converged after 15 iterations
# 188
# Gene converged after 23 iterations
# 105
# Gene converged after 19 iterations
# 178
# Gene converged after 18 iterations
# 112
# Gene converged after 17 iterations
# 31
# Gene converged after 17 iterations
# 43
# Gene converged after 19 iterations
# 26
# Gene converged after 20 iterations
# 126
# Gene converged after 27 iterations
# 153
# Gene converged after 19 iterations
# 172
# Gene converged after 17 iterations
# 141
# Gene converged after 20 iterations
# 65
# Gene converged after 13 iterations
# 42
# Gene converged after 15 iterations
# 34
# Gene converged after 25 iterations
# 101
# Gene converged after 19 iterations
# 72
# Gene converged after 30 iterations
# 186
# Gene converged after 14 iterations
# 82
# Gene converged after 19 iterations
# 145
# Gene converged after 20 iterations
# 171
# Gene converged after 19 iterations
# 30
# Gene converged after 22 iterations
# 92
# Gene converged after 15 iterations
# 50
# Gene converged after 12 iterations
# 36
# Gene converged after 22 iterations
# 54
# Gene converged after 24 iterations
# 8
# Gene converged after 21 iterations
# 118
# Gene converged after 15 iterations
# 61
# Gene converged after 18 iterations
# 123
# Gene converged after 11 iterations
# 4
# Gene converged after 15 iterations
# 154
# Gene converged after 13 iterations
# 66
# Gene converged after 17 iterations
# 161
# Gene converged after 19 iterations
# 117
# Gene converged after 17 iterations
# 6
# Gene converged after 22 iterations
# 164
# Gene converged after 13 iterations
# 185
# Gene converged after 16 iterations
# 37
# Gene converged after 14 iterations
# 125
# Gene converged after 14 iterations
# 142
# Gene converged after 15 iterations
# 29
# Gene converged after 32 iterations
# 147
# Gene converged after 22 iterations
# 110
# Gene converged after 18 iterations
# 25
# Gene converged after 16 iterations
# 15
# Gene converged after 20 iterations
# 149
# Gene converged after 13 iterations
# 113
# Gene converged after 13 iterations
# 39
# Gene converged after 16 iterations
# 138
# Gene converged after 14 iterations
# 106
# Gene converged after 19 iterations
# 56
# Gene converged after 16 iterations
# 89
# Gene converged after 15 iterations
# 86
# Gene converged after 13 iterations
# 19
# Gene converged after 20 iterations
# 173
# Gene converged after 30 iterations
# 160
# Gene converged after 14 iterations
# 94
# Gene converged after 15 iterations
# 148
# Gene converged after 19 iterations
# 128
# Gene converged after 17 iterations
# 143
# Gene converged after 13 iterations
# 184
# Gene converged after 15 iterations
# 124
# Gene converged after 14 iterations
# 85
# Gene converged after 18 iterations
# 7
# Gene converged after 13 iterations
# 157
# Gene converged after 20 iterations
# 121
# Gene converged after 20 iterations
# 17
# Gene converged after 12 iterations
# 83
# Gene converged after 17 iterations
# 2
# Gene converged after 15 iterations
# 104
# Gene converged after 16 iterations
# 167
# Gene converged after 20 iterations
# 78
# Gene converged after 14 iterations
# 76
# Gene converged after 14 iterations
# 35
# Gene converged after 18 iterations
# 68
# Gene converged after 21 iterations
# 187
# Gene converged after 12 iterations
# 70
# Gene converged after 13 iterations
# 69
# Gene converged after 17 iterations
# 140
# Gene converged after 15 iterations
# 179
# Gene converged after 13 iterations
# 60
# Gene converged after 16 iterations
# 98
# Gene converged after 15 iterations
# 108
# Gene converged after 12 iterations
# 103
# Gene converged after 16 iterations
# 119
# Gene converged after 22 iterations
# 41
# Gene converged after 11 iterations
# 55
# Gene converged after 19 iterations
# 91
# Gene converged after 8 iterations
# 90
# Gene converged after 15 iterations
# 135
# Gene converged after 12 iterations
# 99
# Gene converged after 12 iterations
# 169
# Gene converged after 14 iterations
# 33
# Gene converged after 17 iterations
# 79
# Gene converged after 14 iterations
# 144
# Gene converged after 16 iterations
# 44
# Gene converged after 17 iterations
# 59
# Gene converged after 15 iterations
# 77
# Gene converged after 14 iterations
# 48
# Gene converged after 17 iterations
# 45
# Gene converged after 14 iterations
# 23
# Gene converged after 18 iterations
# 166
# Gene converged after 17 iterations
# 97
# Gene converged after 17 iterations
# 21
# Gene converged after 19 iterations
# 120
# Gene converged after 22 iterations
# 130
# Gene converged after 17 iterations
# 134
# Gene converged after 18 iterations
# 175
# Gene converged after 17 iterations
# 95
# Gene converged after 21 iterations
# 165
# Gene converged after 20 iterations
# 27
# Gene converged after 23 iterations
# 53
# Gene converged after 21 iterations
# 5
# Gene converged after 19 iterations
# 46
# Gene converged after 19 iterations
# 156
# Gene converged after 14 iterations
# 115
# Gene converged after 45 iterations
# 182
# Gene converged after 12 iterations
# 0
# Gene converged after 10 iterations
# 64
# Gene converged after 24 iterations
# 127
# Gene converged after 11 iterations
# 137
# Gene converged after 13 iterations
# 139
# Gene converged after 19 iterations
# 88
# Gene converged after 19 iterations
# 105.365895987
# 713697.62626 2924721.73097 -113856.086302 -3524563.27093
# 54
# Gene converged after 26 iterations
# 97
# Gene converged after 28 iterations
# 168
# Gene converged after 16 iterations
# 117
# Gene converged after 19 iterations
# 149
# Gene converged after 22 iterations
# 166
# Gene converged after 21 iterations
# 153
# Gene converged after 29 iterations
# 110
# Gene converged after 25 iterations
# 137
# Gene converged after 15 iterations
# 84
# Gene converged after 28 iterations
# 87
# Gene converged after 20 iterations
# 95
# Gene converged after 20 iterations
# 186
# Gene converged after 19 iterations
# 188
# Gene converged after 27 iterations
# 152
# Gene converged after 25 iterations
# 145
# Gene converged after 19 iterations
# 19
# Gene converged after 24 iterations
# 154
# Gene converged after 21 iterations
# 98
# Gene converged after 27 iterations
# 12
# Gene converged after 13 iterations
# 182
# Gene converged after 18 iterations
# 156
# Gene converged after 36 iterations
# 94
# Gene converged after 23 iterations
# 13
# Gene converged after 21 iterations
# 16
# Gene converged after 19 iterations
# 47
# Gene converged after 30 iterations
# 67
# Gene converged after 19 iterations
# 135
# Gene converged after 29 iterations
# 134
# Gene converged after 26 iterations
# 181
# Gene converged after 18 iterations
# 173
# Gene converged after 20 iterations
# 52
# Gene converged after 16 iterations
# 2
# Gene converged after 17 iterations
# 43
# Gene converged after 31 iterations
# 131
# Gene converged after 21 iterations
# 17
# Gene converged after 19 iterations
# 42
# Gene converged after 27 iterations
# 6
# Gene converged after 20 iterations
# 119
# Gene converged after 17 iterations
# 5
# Gene converged after 19 iterations
# 31
# Gene converged after 20 iterations
# 71
# Gene converged after 20 iterations
# 29
# Gene converged after 20 iterations
# 78
# Gene converged after 16 iterations
# 11
# Gene converged after 24 iterations
# 99
# Gene converged after 17 iterations
# 59
# Gene converged after 31 iterations
# 167
# Gene converged after 18 iterations
# 132
# Gene converged after 14 iterations
# 187
# Gene converged after 21 iterations
# 56
# Gene converged after 22 iterations
# 118
# Gene converged after 21 iterations
# 26
# Gene converged after 24 iterations
# 121
# Gene converged after 21 iterations
# 101
# Gene converged after 23 iterations
# 10
# Gene converged after 18 iterations
# 90
# Gene converged after 24 iterations
# 133
# Gene converged after 18 iterations
# 32
# Gene converged after 20 iterations
# 183
# Gene converged after 22 iterations
# 120
# Gene converged after 26 iterations
# 73
# Gene converged after 18 iterations
# 49
# Gene converged after 18 iterations
# 176
# Gene converged after 21 iterations
# 79
# Gene converged after 26 iterations
# 72
# Gene converged after 20 iterations
# 104
# Gene converged after 18 iterations
# 143
# Gene converged after 20 iterations
# 8
# Gene converged after 26 iterations
# 162
# Gene converged after 39 iterations
# 141
# Gene converged after 19 iterations
# 77
# Gene converged after 21 iterations
# 111
# Gene converged after 24 iterations
# 7
# Gene converged after 15 iterations
# 160
# Gene converged after 24 iterations
# 88
# Gene converged after 27 iterations
# 175
# Gene converged after 24 iterations
# 171
# Gene converged after 22 iterations
# 85
# Gene converged after 24 iterations
# 83
# Gene converged after 25 iterations
# 18
# Gene converged after 24 iterations
# 106
# Gene converged after 24 iterations
# 28
# Gene converged after 20 iterations
# 82
# Gene converged after 18 iterations
# 144
# Gene converged after 20 iterations
# 114
# Gene converged after 25 iterations
# 189
# Gene converged after 25 iterations
# 100
# Gene converged after 26 iterations
# 74
# Gene converged after 16 iterations
# 140
# Gene converged after 23 iterations
# 64
# Gene converged after 32 iterations
# 136
# Gene converged after 25 iterations
# 124
# Gene converged after 25 iterations
# 165
# Gene converged after 16 iterations
# 172
# Gene converged after 22 iterations
# 38
# Gene converged after 22 iterations
# 161
# Gene converged after 18 iterations
# 127
# Gene converged after 23 iterations
# 65
# Gene converged after 24 iterations
# 30
# Gene converged after 26 iterations
# 105
# ...
# 26
# Gene converged after 18 iterations
# 15
# Gene converged after 22 iterations
# 14
# Gene converged after 12 iterations
# 118
# Gene converged after 18 iterations
# 29
# Gene converged after 15 iterations
# 104
# Gene converged after 19 iterations
# 168
# Gene converged after 13 iterations
# 18
# Gene converged after 19 iterations
# 182
# Gene converged after 15 iterations
# 68
# Gene converged after 20 iterations
# 94
# Gene converged after 22 iterations
# 146
# Gene converged after 18 iterations
# 87
# Gene converged after 15 iterations
# 45
# Gene converged after 17 iterations
# 126
# Gene converged after 19 iterations
# 103
# Gene converged after 19 iterations
# 153
# Gene converged after 24 iterations
# 96
# Gene converged after 17 iterations
# 74
# Gene converged after 18 iterations
# 39
# Gene converged after 21 iterations
# 22
# Gene converged after 14 iterations
# 49
# Gene converged after 16 iterations
# 17
# Gene converged after 22 iterations
# 184
# Gene converged after 20 iterations
# 101
# Gene converged after 16 iterations
# 121
# Gene converged after 19 iterations
# 141
# Gene converged after 17 iterations
# 149
# Gene converged after 14 iterations
# 41
# Gene converged after 13 iterations
# 0
# Gene converged after 18 iterations
# 113.976231813
# 666960.425008 -730629238095.0 -133293.940193 730628704428.0
# 83
# Gene converged after 18 iterations
# 150
# Gene converged after 18 iterations
# 148
# Gene converged after 18 iterations
# 2
# Gene converged after 10 iterations
# 24
# Gene converged after 18 iterations
# 21
# Gene converged after 13 iterations
# 68
# Gene converged after 16 iterations
# 37
# Gene converged after 8 iterations
# 141
# Gene converged after 15 iterations
# 154
# Gene converged after 15 iterations
# 65
# Gene converged after 15 iterations
# 149
# Gene converged after 12 iterations
# 178
# Gene converged after 13 iterations
# 103
# Gene converged after 19 iterations
# 33
# Gene converged after 16 iterations
# 5
# Gene converged after 12 iterations
# 124
# Gene converged after 19 iterations
# 80
# Gene converged after 13 iterations
# 10
# Gene converged after 18 iterations
# 29
# Gene converged after 10 iterations
# 161
# Gene converged after 13 iterations
# 135
# Gene converged after 23 iterations
# 137
# Gene converged after 8 iterations
# 116
# Gene converged after 18 iterations
# 112
# Gene converged after 18 iterations
# 88
# Gene converged after 15 iterations
# 45
# Gene converged after 16 iterations
# 12
# Gene converged after 9 iterations
# 143
# Gene converged after 14 iterations
# 31
# Gene converged after 12 iterations
# 19
# Gene converged after 18 iterations
# 121
# Gene converged after 15 iterations
# 100
# Gene converged after 14 iterations
# 127
# Gene converged after 13 iterations
# 134
# Gene converged after 14 iterations
# 58
# Gene converged after 13 iterations
# 41
# Gene converged after 15 iterations
# 102
# Gene converged after 16 iterations
# 22
# Gene converged after 8 iterations
# 23
# Gene converged after 19 iterations
# 77
# Gene converged after 12 iterations
# 51
# Gene converged after 15 iterations
# 46
# Gene converged after 16 iterations
# 114
# Gene converged after 17 iterations
# 166
# Gene converged after 17 iterations
# 54
# Gene converged after 16 iterations
# 168
# Gene converged after 11 iterations
# 60
# Gene converged after 17 iterations
# 163
# Gene converged after 5 iterations
# 18
# Gene converged after 14 iterations
# 169
# Gene converged after 9 iterations
# 50
# Gene converged after 10 iterations
# 63
# Gene converged after 14 iterations
# 81
# Gene converged after 7 iterations
# 170
# Gene converged after 16 iterations
# 72
# Gene converged after 15 iterations
# 123
# Gene converged after 18 iterations
# 106
# Gene converged after 12 iterations
# 49
# Gene converged after 8 iterations
# 101
# Gene converged after 15 iterations
# 184
# Gene converged after 13 iterations
# 0
# Gene converged after 10 iterations
# 57
# Gene converged after 21 iterations
# 6
# Gene converged after 14 iterations
# 38
# Gene converged after 16 iterations
# 131
# Gene converged after 12 iterations
# 172
# Gene converged after 14 iterations
# 73
# Gene converged after 6 iterations
# 56
# Gene converged after 16 iterations
# 75
# Gene converged after 15 iterations
# 93
# Gene converged after 16 iterations
# 94
# Gene converged after 13 iterations
# 126
# Gene converged after 11 iterations
# 62
# Gene converged after 17 iterations
# 20
# Gene converged after 17 iterations
# 47
# Gene converged after 14 iterations
# 40
# Gene converged after 13 iterations
# 99
# Gene converged after 12 iterations
# 117
# Gene converged after 17 iterations
# 55
# Gene converged after 11 iterations
# 69
# Gene converged after 12 iterations
# 109
# Gene converged after 19 iterations
# 98
# Gene converged after 11 iterations
# 176
# Gene converged after 10 iterations
# 108
# Gene converged after 13 iterations
# 160
# Gene converged after 14 iterations
# 76
# Gene converged after 17 iterations
# 36
# Gene converged after 21 iterations
# 157
# Gene converged after 12 iterations
# 70
# Gene converged after 15 iterations
# 15
# Gene converged after 15 iterations
# 130
# Gene converged after 16 iterations
# 110
# Gene converged after 19 iterations
# 90
# Gene converged after 10 iterations
# 119
# Gene converged after 13 iterations
# 11
# Gene converged after 13 iterations
# 67
# Gene converged after 11 iterations
# 25
# Gene converged after 12 iterations
# 82
# Gene converged after 15 iterations
# 182
# Gene converged after 13 iterations
# 171
# Gene converged after 16 iterations
# 43
# Gene converged after 14 iterations
# 4
# Gene converged after 16 iterations
# 167
# Gene converged after 10 iterations
# 133
# Gene converged after 14 iterations
# 84
# Gene converged after 16 iterations
# 115
# Gene converged after 9 iterations
# 179
# Gene converged after 16 iterations
# 104
# Gene converged after 14 iterations
# 152
# Gene converged after 18 iterations
# 146
# Gene converged after 11 iterations
# 111
# Gene converged after 14 iterations
# 120
# Gene converged after 15 iterations
# 144
# Gene converged after 16 iterations
# 142
# Gene converged after 14 iterations
# 9
# Gene converged after 13 iterations
# 66
# Gene converged after 18 iterations
# 183
# Gene converged after 18 iterations
# 140
# Gene converged after 15 iterations
# 185
# Gene converged after 14 iterations
# 155
# Gene converged after 14 iterations
# 151
# Gene converged after 17 iterations
# 32
# Gene converged after 16 iterations
# 59
# Gene converged after 15 iterations
# 162
# Gene converged after 16 iterations
# 147
# Gene converged after 15 iterations
# 42
# Gene converged after 18 iterations
# 30
# Gene converged after 18 iterations
# 122
# Gene converged after 13 iterations
# 14
# Gene converged after 10 iterations
# 26
# Gene converged after 13 iterations
# 158
# Gene converged after 12 iterations
# 139
# Gene converged after 17 iterations
# 17
# Gene converged after 9 iterations
# 16
# Gene converged after 16 iterations
# 3
# Gene converged after 15 iterations
# 107
# Gene converged after 14 iterations
# 35
# Gene converged after 13 iterations
# 118
# Gene converged after 16 iterations
# 129
# Gene converged after 15 iterations
# 89
# Gene converged after 13 iterations
# 128
# Gene converged after 14 iterations
# 105
# Gene converged after 18 iterations
# 27
# Gene converged after 14 iterations
# 95
# Gene converged after 12 iterations
# 34
# Gene converged after 22 iterations
# 44
# Gene converged after 20 iterations
# 173
# Gene converged after 12 iterations
# 13
# Gene converged after 9 iterations
# 188
# Gene converged after 18 iterations
# 78
# Gene converged after 19 iterations
# 165
# Gene converged after 13 iterations
# 53
# Gene converged after 15 iterations
# 28
# Gene converged after 14 iterations
# 175
# Gene converged after 14 iterations
# 86
# Gene converged after 13 iterations
# 180
# Gene converged after 14 iterations
# 113
# Gene converged after 13 iterations
# 52
# Gene converged after 9 iterations
# 79
# Gene converged after 14 iterations
# 153
# Gene converged after 12 iterations
# 85
# Gene converged after 19 iterations
# 125
# Gene converged after 13 iterations
# 164
# Gene converged after 18 iterations
# 177
# Gene converged after 12 iterations
# 174
# Gene converged after 18 iterations
# 7
# Gene converged after 14 iterations
# 96
# Gene converged after 10 iterations
# 87
# Gene converged after 13 iterations
# 48
# Gene converged after 12 iterations
# 156
# Gene converged after 11 iterations
# 8
# Gene converged after 18 iterations
# 39
# Gene converged after 15 iterations
# 1
# Gene converged after 11 iterations
# 71
# Gene converged after 12 iterations
# 132
# Gene converged after 10 iterations
# 159
# Gene converged after 16 iterations
# 97
# Gene converged after 12 iterations
# 91
# Gene converged after 5 iterations
# 61
# Gene converged after 16 iterations
# 145
# Gene converged after 15 iterations
# 136
# Gene converged after 13 iterations
# 187
# Gene converged after 14 iterations
# 92
# Gene converged after 14 iterations
# 138
# Gene converged after 10 iterations
# 186
# Gene converged after 14 iterations
# 181
# Gene converged after 14 iterations
# 64
# Gene converged after 15 iterations
# 189
# Gene converged after 17 iterations
# 74
# Gene converged after 10 iterations
# 88.9058029652
# 618957.636857 2.95925020423e+12 -106363.390176 -2.95925071682e+12
# 94
# Gene converged after 23 iterations
# 188
# Gene converged after 59 iterations
# 3
# Gene converged after 54 iterations
# 137
# Gene converged after 24 iterations
# 39
# Gene converged after 38 iterations
# 16
# Gene converged after 29 iterations
# 106
# Gene converged after 19 iterations
# 87
# Gene converged after 35 iterations
# 7
# Gene converged after 45 iterations
# 140
# Gene converged after 51 iterations
# 156
# Gene converged after 35 iterations
# 22
# Gene converged after 15 iterations
# 99
# Gene converged after 30 iterations
# 1
# Gene converged after 17 iterations
# 141
# Gene converged after 29 iterations
# 24
# Gene converged after 38 iterations
# 93
# Gene converged after 45 iterations
# 82
# Gene converged after 31 iterations
# 148
# Gene converged after 31 iterations
# 58
# Gene converged after 28 iterations
# 124
# Gene converged after 44 iterations
# 112
# Gene converged after 42 iterations
# 41
# Gene converged after 45 iterations
# 111
# Gene converged after 35 iterations
# 154
# Gene converged after 48 iterations
# 153
# Gene converged after 35 iterations
# 81
# Gene converged after 14 iterations
# 31
# Gene converged after 33 iterations
# 83
# Gene converged after 56 iterations
# 175
# Gene converged after 29 iterations
# 180
# Gene converged after 22 iterations
# 170
# Gene converged after 33 iterations
# 171
# Gene converged after 36 iterations
# 147
# Gene converged after 26 iterations
# 53
# Gene converged after 31 iterations
# 61
# Gene converged after 37 iterations
# 121
# Gene converged after 34 iterations
# 177
# Gene converged after 21 iterations
# 10
# Gene converged after 36 iterations
# 116
# Gene converged after 32 iterations
# 151
# Gene converged after 32 iterations
# 179
# Gene converged after 42 iterations
# 45
# Gene converged after 41 iterations
# 68
# Gene converged after 34 iterations
# 167
# Gene converged after 18 iterations
# 40
# Gene converged after 36 iterations
# 161
# Gene converged after 26 iterations
# 163
# Gene converged after 24 iterations
# 176
# Gene converged after 21 iterations
# 66
# Gene converged after 37 iterations
# 52
# Gene converged after 30 iterations
# 4
# Gene converged after 32 iterations
# 160
# Gene converged after 48 iterations
# 6
# Gene converged after 45 iterations
# 155
# Gene converged after 40 iterations
# 14
# Gene converged after 14 iterations
# 54
# Gene converged after 50 iterations
# 36
# Gene converged after 48 iterations
# 110
# Gene converged after 34 iterations
# 132
# Gene converged after 20 iterations
# 64
# Gene converged after 45 iterations
# 126
# Gene converged after 23 iterations
# 79
# Gene converged after 45 iterations
# 60
# Gene converged after 35 iterations
# 97
# Gene converged after 31 iterations
# 62
# Gene converged after 33 iterations
# 122
# Gene converged after 22 iterations
# 34
# Gene converged after 44 iterations
# 108
# Gene converged after 24 iterations
# 19
# Gene converged after 49 iterations
# 186
# Gene converged after 44 iterations
# 2
# Gene converged after 30 iterations
# 57
# Gene converged after 62 iterations
# 74
# Gene converged after 28 iterations
# 157
# Gene converged after 25 iterations
# 42
# Gene converged after 31 iterations
# 135
# Gene converged after 48 iterations
# 0
# Gene converged after 24 iterations
# 139
# Gene converged after 35 iterations
# 178
# Gene converged after 45 iterations
# 18
# Gene converged after 32 iterations
# 80
# Gene converged after 47 iterations
# 181
# Gene converged after 35 iterations
# 89
# Gene converged after 12 iterations
# 114
# Gene converged after 37 iterations
# 78
# Gene converged after 41 iterations
# 143
# Gene converged after 49 iterations
# 159
# Gene converged after 29 iterations
# 65
# Gene converged after 56 iterations
# 33
# Gene converged after 53 iterations
# 5
# Gene converged after 29 iterations
# 96
# Gene converged after 17 iterations
# 125
# Gene converged after 25 iterations
# 48
# Gene converged after 24 iterations
# 12
# Gene converged after 15 iterations
# 183
# Gene converged after 43 iterations
# 172
# Gene converged after 34 iterations
# 150
# Gene converged after 37 iterations
# 30
# Gene converged after 48 iterations
# 134
# Gene converged after 29 iterations
# 127
# Gene converged after 34 iterations
# 101
# Gene converged after 41 iterations
# 119
# Gene converged after 38 iterations
# 69
# Gene converged after 23 iterations
# 86
# Gene converged after 19 iterations
# 91
# Gene converged after 10 iterations
# 76
# Gene converged after 44 iterations
# 168
# Gene converged after 12 iterations
# 129
# Gene converged after 26 iterations
# 23
# Gene converged after 34 iterations
# 107
# Gene converged after 47 iterations
# 104
# Gene converged after 29 iterations
# 38
# Gene converged after 29 iterations
# 70
# Gene converged after 30 iterations
# 59
# Gene converged after 50 iterations
# 95
# Gene converged after 19 iterations
# 9
# Gene converged after 20 iterations
# 55
# Gene converged after 19 iterations
# 21
# Gene converged after 30 iterations
# 17
# Gene converged after 20 iterations
# 128
# Gene converged after 25 iterations
# 164
# Gene converged after 53 iterations
# 144
# Gene converged after 26 iterations
# 50
# Gene converged after 42 iterations
# 185
# Gene converged after 44 iterations
# 46
# Gene converged after 28 iterations
# 13
# Gene converged after 22 iterations
# 133
# Gene converged after 24 iterations
# 103
# Gene converged after 57 iterations
# 174
# Gene converged after 38 iterations
# 166
# Gene converged after 48 iterations
# 120
# Gene converged after 35 iterations
# 100
# Gene converged after 33 iterations
# 98
# Gene converged after 35 iterations
# 118
# Gene converged after 29 iterations
# 77
# Gene converged after 35 iterations
# 136
# Gene converged after 22 iterations
# 117
# Gene converged after 60 iterations
# 182
# Gene converged after 35 iterations
# 28
# Gene converged after 57 iterations
# 115
# Gene converged after 21 iterations
# 149
# Gene converged after 27 iterations
# 20
# Gene converged after 39 iterations
# 131
# Gene converged after 23 iterations
# 56
# Gene converged after 34 iterations
# 102
# Gene converged after 30 iterations
# 145
# Gene converged after 39 iterations
# 29
# Gene converged after 29 iterations
# 85
# Gene converged after 46 iterations
# 27
# Gene converged after 27 iterations
# 35
# Gene converged after 24 iterations
# 43
# Gene converged after 27 iterations
# 130
# Gene converged after 32 iterations
# 44
# Gene converged after 31 iterations
# 72
# Gene converged after 39 iterations
# 51
# Gene converged after 25 iterations
# 113
# Gene converged after 31 iterations
# 63
# Gene converged after 25 iterations
# 162
# Gene converged after 37 iterations
# 47
# Gene converged after 42 iterations
# 8
# Gene converged after 32 iterations
# 90
# Gene converged after 18 iterations
# 15
# Gene converged after 42 iterations
# 152
# Gene converged after 54 iterations
# 173
# Gene converged after 27 iterations
# 25
# Gene converged after 20 iterations
# 11
# Gene converged after 23 iterations
# 146
# Gene converged after 20 iterations
# 123
# Gene converged after 36 iterations
# 165
# Gene converged after 25 iterations
# 84
# Gene converged after 64 iterations
# 109
# Gene converged after 50 iterations
# 184
# Gene converged after 46 iterations
# 88
# Gene converged after 46 iterations
# 71
# Gene converged after 29 iterations
# 105
# Gene converged after 38 iterations
# 37
# Gene converged after 35 iterations
# 32
# Gene converged after 84 iterations
# 73
# Gene converged after 18 iterations
# 158
# Gene converged after 38 iterations
# 26
# Gene converged after 32 iterations
# 187
# Gene converged after 58 iterations
# 138
# Gene converged after 30 iterations
# 67
# Gene converged after 22 iterations
# 49
# Gene converged after 19 iterations
# 169
# Gene converged after 25 iterations
# 142
# Gene converged after 25 iterations
# 189
# Gene converged after 37 iterations
# 75
# Gene converged after 50 iterations
# 92
# Gene converged after 35 iterations
# 204.409745932
# 725898.474973 -1.2413376583e+13 -169087.916368 1.24133760262e+13

# %%
output = "VI/VI_stochatic_K4"

np.savez('%s-ELBO' %output, genes.ELBO)
np.savez('%s-t' % output, genes.T)
np.savez('%s-gamma' % output, genes.gammma)
np.savez('%s-lambda' % output, genes.lambbda)
np.savez('%s-phi' % output, genes.phi)
np.savez('%s-data-used' % output, genes.Wn)
np.savez('%s-vocabulary-to-int' % output, genes.vocabulary_in_int)



with open("%s.pickle" % output, 'wb') as handle:
    pickle.dump(genes, handle)
